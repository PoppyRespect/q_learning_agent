# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/gold_data.csv', encoding='GBK')
df.head()
# Out:
#          Date   Close    Open    High     Low    Vol     Per
# 0  2012年1月20日  1663.7  1652.8  1664.3  1652.8  0.01K   0.58%
# 1  2012年1月23日  1678.0  1676.9  1680.0  1669.9  0.01K   0.86%
# 2  2012年1月24日  1664.2  1666.9  1668.2  1664.4  0.01K  -0.82%
# 3  2012年1月25日  1699.8  1673.0  1706.2  1658.3  0.24K   2.14%
# 4  2012年1月26日  1726.3  1729.0  1729.0  1721.0  0.02K   1.56%

# %%
from collections import deque
import random


class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        #输入feed 输出action的概率分布
        self.logits = tf.layers.dense(feed, self.action_size)
        #计算损失
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        #梯度下降
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        #随机采取行动和预测行动相结合
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        """
       核心函数 
        """
        mini_batch = []
        l = len(self.memory)
        #当sell.memmory 长度大于batch_size时进入循环
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        #跟新当前网络mini_batch次
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0#总利润
            inventory = []#投资列表
            state = self.get_state(0)#第一个状态
            starting_money = initial_money#开始资金
            for t in range(0, len(self.trend) - 1, self.skip):#完成一局游戏的循环
                action = self.act(state)#预测当前状态下的action
                next_state = self.get_state(t + 1)# 获取下一个状态
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):#如果是买信号 and 资金充足 
                    inventory.append(self.trend[t])#更新inventory
                    starting_money -= self.trend[t]#更新starting_money
                
                elif action == 2 and len(inventory) > 0:#如果是卖信号且有库存
                    bought_price = inventory.pop(0)#最晚的一笔交易
                    total_profit += self.trend[t] - bought_price#最旺那笔交易的利润
                    starting_money += self.trend[t]#更新starting_money
                    
                invest = ((starting_money - initial_money) / initial_money)#最晚那笔交易的盈利率
                
                #更新记忆额，类似于Q-learning中的Q表 （state, action, invest,next_state）
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
                
            #隔一个checkpoint, 打印total_profit,cost,starting_money
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))
# Out:
# 0

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-9-9934fc4f9176>:26: dense (from tensorflow.python.keras.legacy_tf_layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# epoch: 10, total rewards: 1850.650000.3, cost: 1.138304, total money: 11850.650000
# epoch: 20, total rewards: 870.750000.3, cost: 0.465532, total money: 10870.750000
# epoch: 30, total rewards: 379.800000.3, cost: 0.267367, total money: 10379.800000
# epoch: 40, total rewards: 918.150000.3, cost: 0.198401, total money: 10918.150000
# epoch: 50, total rewards: 82.950000.3, cost: 0.156209, total money: 10082.950000
# epoch: 60, total rewards: 564.660000.3, cost: 0.113436, total money: 10564.660000
# epoch: 70, total rewards: 586.510000.3, cost: 0.095100, total money: 10586.510000
# epoch: 80, total rewards: 1112.460000.3, cost: 0.088213, total money: 11112.460000
# epoch: 90, total rewards: 236.160000.3, cost: 0.063571, total money: 10236.160000
# epoch: 100, total rewards: 711.060000.3, cost: 0.053318, total money: 10711.060000
# epoch: 110, total rewards: 561.660000.3, cost: 0.145294, total money: 10561.660000
# epoch: 120, total rewards: 75.060000.3, cost: 0.047006, total money: 10075.060000
# epoch: 130, total rewards: 528.250000.3, cost: 0.046385, total money: 10528.250000
# epoch: 140, total rewards: 270.380000.3, cost: 0.041040, total money: 10270.380000
# epoch: 150, total rewards: 484.410000.3, cost: 0.117825, total money: 10484.410000
# epoch: 160, total rewards: -322.390000.3, cost: 0.098991, total money: 9677.610000
# epoch: 170, total rewards: 442.360000.3, cost: 0.059474, total money: 10442.360000
# epoch: 180, total rewards: 478.880000.3, cost: 0.024979, total money: 10478.880000
# epoch: 190, total rewards: 933.170000.3, cost: 0.028625, total money: 10933.170000
# epoch: 200, total rewards: 626.480000.3, cost: 0.025234, total money: 10626.480000

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 1: buy 1 unit at price 1678.000000, total balance 8322.000000
# day 3, sell 1 unit at price 1699.800000, investment 1.299166 %, total balance 10021.800000,
# day 4: buy 1 unit at price 1726.300000, total balance 8295.500000
# day 7, sell 1 unit at price 1737.800000, investment 0.666165 %, total balance 10033.300000,
# day 8: buy 1 unit at price 1747.100000, total balance 8286.200000
# day 10: buy 1 unit at price 1737.900000, total balance 6548.300000
# day 11: buy 1 unit at price 1722.800000, total balance 4825.500000
# day 12, sell 1 unit at price 1746.400000, investment -0.040066 %, total balance 6571.900000,
# day 14, sell 1 unit at price 1739.000000, investment 0.063295 %, total balance 8310.900000,
# day 15: buy 1 unit at price 1723.300000, total balance 6587.600000
# day 16: buy 1 unit at price 1723.000000, total balance 4864.600000
# day 17: buy 1 unit at price 1715.900000, total balance 3148.700000
# day 18, sell 1 unit at price 1726.300000, investment 0.203158 %, total balance 4875.000000,
# day 19: buy 1 unit at price 1726.800000, total balance 3148.200000
# day 20: buy 1 unit at price 1724.500000, total balance 1423.700000
# day 21, sell 1 unit at price 1757.100000, investment 1.961353 %, total balance 3180.800000,
# day 23, sell 1 unit at price 1784.900000, investment 3.592571 %, total balance 4965.700000,
# day 25, sell 1 unit at price 1773.600000, investment 3.362667 %, total balance 6739.300000,
# day 26: buy 1 unit at price 1787.000000, total balance 4952.300000
# day 27: buy 1 unit at price 1709.900000, total balance 3242.400000
# day 28, sell 1 unit at price 1721.100000, investment -0.330090 %, total balance 4963.500000,
# day 30: buy 1 unit at price 1703.000000, total balance 3260.500000
# day 31, sell 1 unit at price 1671.400000, investment -3.079153 %, total balance 4931.900000,
# day 32, sell 1 unit at price 1683.300000, investment -5.803022 %, total balance 6615.200000,
# day 34: buy 1 unit at price 1710.900000, total balance 4904.300000
# day 35: buy 1 unit at price 1699.200000, total balance 3205.100000
# day 36, sell 1 unit at price 1693.700000, investment -0.947424 %, total balance 4898.800000,
# day 38, sell 1 unit at price 1659.100000, investment -2.577804 %, total balance 6557.900000,
# day 39: buy 1 unit at price 1655.500000, total balance 4902.400000
# day 40, sell 1 unit at price 1666.900000, investment -2.571746 %, total balance 6569.300000,
# day 41: buy 1 unit at price 1646.700000, total balance 4922.600000
# day 42, sell 1 unit at price 1650.000000, investment -2.895480 %, total balance 6572.600000,
# day 43, sell 1 unit at price 1642.300000, investment -0.797342 %, total balance 8214.900000,
# day 44, sell 1 unit at price 1662.300000, investment 0.947349 %, total balance 9877.200000,
# day 45: buy 1 unit at price 1685.500000, total balance 8191.700000
# day 46, sell 1 unit at price 1684.800000, investment -0.041531 %, total balance 9876.500000,
# day 52: buy 1 unit at price 1612.300000, total balance 8264.200000
# day 53, sell 1 unit at price 1628.500000, investment 1.004776 %, total balance 9892.700000,
# day 54: buy 1 unit at price 1642.500000, total balance 8250.200000
# day 56, sell 1 unit at price 1659.000000, investment 1.004566 %, total balance 9909.200000,
# day 58: buy 1 unit at price 1659.100000, total balance 8250.100000
# day 60: buy 1 unit at price 1650.300000, total balance 6599.800000
# day 62: buy 1 unit at price 1640.600000, total balance 4959.200000
# day 63, sell 1 unit at price 1642.100000, investment -1.024652 %, total balance 6601.300000,
# day 64, sell 1 unit at price 1631.900000, investment -1.114949 %, total balance 8233.200000,
# day 65: buy 1 unit at price 1643.000000, total balance 6590.200000
# day 66, sell 1 unit at price 1641.400000, investment 0.048763 %, total balance 8231.600000,
# day 67, sell 1 unit at price 1659.600000, investment 1.010347 %, total balance 9891.200000,
# day 68: buy 1 unit at price 1664.000000, total balance 8227.200000
# day 70, sell 1 unit at price 1661.700000, investment -0.138221 %, total balance 9888.900000,
# day 73: buy 1 unit at price 1644.700000, total balance 8244.200000
# day 74, sell 1 unit at price 1638.600000, investment -0.370888 %, total balance 9882.800000,
# day 79: buy 1 unit at price 1560.600000, total balance 8322.200000
# day 81: buy 1 unit at price 1536.200000, total balance 6786.000000
# day 82: buy 1 unit at price 1574.500000, total balance 5211.500000
# day 84, sell 1 unit at price 1588.400000, investment 1.781366 %, total balance 6799.900000,
# day 86, sell 1 unit at price 1548.100000, investment 0.774639 %, total balance 8348.000000,
# day 89: buy 1 unit at price 1548.600000, total balance 6799.400000
# day 91, sell 1 unit at price 1562.600000, investment -0.755795 %, total balance 8362.000000,
# day 93, sell 1 unit at price 1612.200000, investment 4.106935 %, total balance 9974.200000,
# day 106: buy 1 unit at price 1564.500000, total balance 8409.700000
# day 108, sell 1 unit at price 1587.500000, investment 1.470118 %, total balance 9997.200000,
# day 109: buy 1 unit at price 1574.000000, total balance 8423.200000
# day 110, sell 1 unit at price 1577.500000, investment 0.222363 %, total balance 10000.700000,
# day 120: buy 1 unit at price 1564.900000, total balance 8435.800000
# day 121: buy 1 unit at price 1591.600000, total balance 6844.200000
# day 122, sell 1 unit at price 1591.200000, investment 1.680619 %, total balance 8435.400000,
# day 123, sell 1 unit at price 1589.100000, investment -0.157075 %, total balance 10024.500000,
# day 129: buy 1 unit at price 1608.000000, total balance 8416.500000
# day 130: buy 1 unit at price 1615.000000, total balance 6801.500000
# day 131: buy 1 unit at price 1617.900000, total balance 5183.600000
# day 132: buy 1 unit at price 1619.700000, total balance 3563.900000
# day 133, sell 1 unit at price 1610.500000, investment 0.155473 %, total balance 5174.400000,
# day 134: buy 1 unit at price 1603.700000, total balance 3570.700000
# day 136, sell 1 unit at price 1606.000000, investment -0.557276 %, total balance 5176.700000,
# day 137, sell 1 unit at price 1612.900000, investment -0.309043 %, total balance 6789.600000,
# day 139, sell 1 unit at price 1612.900000, investment -0.419831 %, total balance 8402.500000,
# day 141, sell 1 unit at price 1619.700000, investment 0.997693 %, total balance 10022.200000,
# day 142: buy 1 unit at price 1609.600000, total balance 8412.600000
# day 143, sell 1 unit at price 1599.400000, investment -0.633698 %, total balance 10012.000000,
# day 146: buy 1 unit at price 1616.300000, total balance 8395.700000
# day 147, sell 1 unit at price 1620.100000, investment 0.235105 %, total balance 10015.800000,
# day 148: buy 1 unit at price 1639.900000, total balance 8375.900000
# day 150, sell 1 unit at price 1669.600000, investment 1.811086 %, total balance 10045.500000,
# day 151: buy 1 unit at price 1669.800000, total balance 8375.700000
# day 152: buy 1 unit at price 1672.400000, total balance 6703.300000
# day 154, sell 1 unit at price 1659.800000, investment -0.598874 %, total balance 8363.100000,
# day 155, sell 1 unit at price 1653.500000, investment -1.130112 %, total balance 10016.600000,
# day 158: buy 1 unit at price 1690.800000, total balance 8325.800000
# day 159: buy 1 unit at price 1702.600000, total balance 6623.200000
# day 161: buy 1 unit at price 1728.700000, total balance 4894.500000
# day 162, sell 1 unit at price 1731.800000, investment 2.424888 %, total balance 6626.300000,
# day 163: buy 1 unit at price 1730.600000, total balance 4895.700000
# day 165: buy 1 unit at price 1769.800000, total balance 3125.900000
# day 166: buy 1 unit at price 1767.700000, total balance 1358.200000
# day 167, sell 1 unit at price 1768.400000, investment 3.864678 %, total balance 3126.600000,
# day 170, sell 1 unit at price 1775.500000, investment 2.707237 %, total balance 4902.100000,
# day 171: buy 1 unit at price 1762.100000, total balance 3140.000000
# day 172, sell 1 unit at price 1763.800000, investment 1.918410 %, total balance 4903.800000,
# day 173, sell 1 unit at price 1750.600000, investment -1.084868 %, total balance 6654.400000,
# day 174, sell 1 unit at price 1777.600000, investment 0.560050 %, total balance 8432.000000,
# day 175: buy 1 unit at price 1771.100000, total balance 6660.900000
# day 176, sell 1 unit at price 1780.500000, investment 1.044209 %, total balance 8441.400000,
# day 177, sell 1 unit at price 1772.700000, investment 0.090339 %, total balance 10214.100000,
# day 178: buy 1 unit at price 1777.300000, total balance 8436.800000
# day 180: buy 1 unit at price 1778.600000, total balance 6658.200000
# day 181, sell 1 unit at price 1773.500000, investment -0.213807 %, total balance 8431.700000,
# day 182, sell 1 unit at price 1763.000000, investment -0.877094 %, total balance 10194.700000,
# day 183: buy 1 unit at price 1763.200000, total balance 8431.500000
# day 184, sell 1 unit at price 1768.800000, investment 0.317604 %, total balance 10200.300000,
# day 185: buy 1 unit at price 1758.000000, total balance 8442.300000
# day 186, sell 1 unit at price 1736.000000, investment -1.251422 %, total balance 10178.300000,
# day 192: buy 1 unit at price 1708.300000, total balance 8470.000000
# day 193, sell 1 unit at price 1700.500000, investment -0.456594 %, total balance 10170.500000,
# day 194: buy 1 unit at price 1712.000000, total balance 8458.500000
# day 195: buy 1 unit at price 1710.900000, total balance 6747.600000
# day 196, sell 1 unit at price 1707.700000, investment -0.251168 %, total balance 8455.300000,
# day 198, sell 1 unit at price 1717.500000, investment 0.385762 %, total balance 10172.800000,
# day 205: buy 1 unit at price 1730.300000, total balance 8442.500000
# day 207, sell 1 unit at price 1724.200000, investment -0.352540 %, total balance 10166.700000,
# day 214: buy 1 unit at price 1751.300000, total balance 8415.400000
# day 216: buy 1 unit at price 1742.200000, total balance 6673.200000
# day 217: buy 1 unit at price 1716.500000, total balance 4956.700000
# day 218, sell 1 unit at price 1727.200000, investment -1.376121 %, total balance 6683.900000,
# day 220, sell 1 unit at price 1719.600000, investment -1.297210 %, total balance 8403.500000,
# day 221, sell 1 unit at price 1694.400000, investment -1.287504 %, total balance 10097.900000,
# day 223: buy 1 unit at price 1700.300000, total balance 8397.600000
# day 224: buy 1 unit at price 1704.000000, total balance 6693.600000
# day 225: buy 1 unit at price 1713.000000, total balance 4980.600000
# day 226, sell 1 unit at price 1708.200000, investment 0.464624 %, total balance 6688.800000,
# day 227, sell 1 unit at price 1716.600000, investment 0.739437 %, total balance 8405.400000,
# day 228: buy 1 unit at price 1695.600000, total balance 6709.800000
# day 231, sell 1 unit at price 1669.500000, investment -2.539405 %, total balance 8379.300000,
# day 232: buy 1 unit at price 1666.500000, total balance 6712.800000
# day 233, sell 1 unit at price 1644.900000, investment -2.990092 %, total balance 8357.700000,
# day 234, sell 1 unit at price 1659.100000, investment -0.444044 %, total balance 10016.800000,
# day 235: buy 1 unit at price 1658.600000, total balance 8358.200000
# day 236, sell 1 unit at price 1659.800000, investment 0.072350 %, total balance 10018.000000,
# day 237: buy 1 unit at price 1662.600000, total balance 8355.400000
# day 238: buy 1 unit at price 1654.900000, total balance 6700.500000
# day 240: buy 1 unit at price 1687.900000, total balance 5012.600000
# day 241, sell 1 unit at price 1673.700000, investment 0.667629 %, total balance 6686.300000,
# day 242, sell 1 unit at price 1648.100000, investment -0.410901 %, total balance 8334.400000,
# day 243, sell 1 unit at price 1645.500000, investment -2.511997 %, total balance 9979.900000,
# day 248: buy 1 unit at price 1668.900000, total balance 8311.000000
# day 251, sell 1 unit at price 1690.400000, investment 1.288274 %, total balance 10001.400000,
# day 252: buy 1 unit at price 1686.600000, total balance 8314.800000
# day 253, sell 1 unit at price 1692.800000, investment 0.367603 %, total balance 10007.600000,
# day 258: buy 1 unit at price 1660.700000, total balance 8346.900000
# day 260, sell 1 unit at price 1660.600000, investment -0.006022 %, total balance 10007.500000,
# day 264: buy 1 unit at price 1677.700000, total balance 8329.800000
# day 265: buy 1 unit at price 1670.400000, total balance 6659.400000
# day 266: buy 1 unit at price 1666.000000, total balance 4993.400000
# day 267: buy 1 unit at price 1648.200000, total balance 3345.200000
# day 268, sell 1 unit at price 1648.700000, investment -1.728557 %, total balance 4993.900000,
# day 269, sell 1 unit at price 1644.200000, investment -1.568487 %, total balance 6638.100000,
# day 270: buy 1 unit at price 1634.700000, total balance 5003.400000
# day 271, sell 1 unit at price 1608.800000, investment -3.433373 %, total balance 6612.200000,
# day 272, sell 1 unit at price 1603.600000, investment -2.705982 %, total balance 8215.800000,
# day 273, sell 1 unit at price 1577.600000, investment -3.492996 %, total balance 9793.400000,
# day 274: buy 1 unit at price 1578.200000, total balance 8215.200000
# day 275: buy 1 unit at price 1572.400000, total balance 6642.800000
# day 276, sell 1 unit at price 1586.200000, investment 0.506907 %, total balance 8229.000000,
# day 279, sell 1 unit at price 1577.700000, investment 0.337064 %, total balance 9806.700000,
# day 287: buy 1 unit at price 1591.500000, total balance 8215.200000
# day 288, sell 1 unit at price 1588.300000, investment -0.201068 %, total balance 9803.500000,
# day 289: buy 1 unit at price 1590.600000, total balance 8212.900000
# day 290, sell 1 unit at price 1592.500000, investment 0.119452 %, total balance 9805.400000,
# day 291: buy 1 unit at price 1604.600000, total balance 8200.800000
# day 292, sell 1 unit at price 1611.300000, investment 0.417550 %, total balance 9812.100000,
# day 295: buy 1 unit at price 1606.200000, total balance 8205.900000
# day 296: buy 1 unit at price 1604.600000, total balance 6601.300000
# day 297, sell 1 unit at price 1595.800000, investment -0.647491 %, total balance 8197.100000,
# day 298, sell 1 unit at price 1606.200000, investment 0.099713 %, total balance 9803.300000,
# day 304: buy 1 unit at price 1575.400000, total balance 8227.900000
# day 305, sell 1 unit at price 1572.000000, investment -0.215818 %, total balance 9799.900000,
# day 306: buy 1 unit at price 1586.200000, total balance 8213.700000
# day 308: buy 1 unit at price 1564.300000, total balance 6649.400000
# day 310: buy 1 unit at price 1360.600000, total balance 5288.800000
# day 312, sell 1 unit at price 1382.200000, investment -12.860925 %, total balance 6671.000000,
# day 313: buy 1 unit at price 1392.000000, total balance 5279.000000
# day 314, sell 1 unit at price 1395.300000, investment -10.803554 %, total balance 6674.300000,
# day 315, sell 1 unit at price 1421.000000, investment 4.439218 %, total balance 8095.300000,
# day 316: buy 1 unit at price 1408.600000, total balance 6686.700000
# day 317: buy 1 unit at price 1423.400000, total balance 5263.300000
# day 320, sell 1 unit at price 1467.400000, investment 5.416667 %, total balance 6730.700000,
# day 321, sell 1 unit at price 1472.200000, investment 4.515121 %, total balance 8202.900000,
# day 322: buy 1 unit at price 1446.300000, total balance 6756.600000
# day 323, sell 1 unit at price 1467.700000, investment 3.112266 %, total balance 8224.300000,
# day 325, sell 1 unit at price 1468.100000, investment 1.507294 %, total balance 9692.400000,
# day 326: buy 1 unit at price 1449.000000, total balance 8243.400000
# day 327, sell 1 unit at price 1473.900000, investment 1.718427 %, total balance 9717.300000,
# day 334: buy 1 unit at price 1364.900000, total balance 8352.400000
# day 335, sell 1 unit at price 1384.300000, investment 1.421350 %, total balance 9736.700000,
# day 337: buy 1 unit at price 1367.600000, total balance 8369.100000
# day 338, sell 1 unit at price 1392.000000, investment 1.784147 %, total balance 9761.100000,
# day 341: buy 1 unit at price 1379.100000, total balance 8382.000000
# day 342, sell 1 unit at price 1391.300000, investment 0.884635 %, total balance 9773.300000,
# day 344: buy 1 unit at price 1392.600000, total balance 8380.700000
# day 345, sell 1 unit at price 1411.700000, investment 1.371535 %, total balance 9792.400000,
# day 349: buy 1 unit at price 1383.000000, total balance 8409.400000
# day 350: buy 1 unit at price 1386.200000, total balance 7023.200000
# day 351: buy 1 unit at price 1377.000000, total balance 5646.200000
# day 353, sell 1 unit at price 1377.600000, investment -0.390456 %, total balance 7023.800000,
# day 355, sell 1 unit at price 1382.800000, investment -0.245275 %, total balance 8406.600000,
# day 356: buy 1 unit at price 1366.600000, total balance 7040.000000
# day 357, sell 1 unit at price 1373.600000, investment -0.246914 %, total balance 8413.600000,
# day 358: buy 1 unit at price 1285.900000, total balance 7127.700000
# day 359, sell 1 unit at price 1291.600000, investment -5.488073 %, total balance 8419.300000,
# day 361: buy 1 unit at price 1274.800000, total balance 7144.500000
# day 362, sell 1 unit at price 1229.600000, investment -4.378256 %, total balance 8374.100000,
# day 363, sell 1 unit at price 1211.400000, investment -4.973329 %, total balance 9585.500000,
# day 365: buy 1 unit at price 1255.900000, total balance 8329.600000
# day 367, sell 1 unit at price 1252.100000, investment -0.302572 %, total balance 9581.700000,
# day 372: buy 1 unit at price 1247.400000, total balance 8334.300000
# day 373: buy 1 unit at price 1280.100000, total balance 7054.200000
# day 374, sell 1 unit at price 1277.800000, investment 2.437069 %, total balance 8332.000000,
# day 375: buy 1 unit at price 1283.800000, total balance 7048.200000
# day 376, sell 1 unit at price 1290.800000, investment 0.835872 %, total balance 8339.000000,
# day 377, sell 1 unit at price 1277.900000, investment -0.459573 %, total balance 9616.900000,
# day 389: buy 1 unit at price 1310.600000, total balance 8306.300000
# day 390: buy 1 unit at price 1302.600000, total balance 7003.700000
# day 391, sell 1 unit at price 1283.200000, investment -2.090646 %, total balance 8286.900000,
# day 392, sell 1 unit at price 1286.100000, investment -1.266697 %, total balance 9573.000000,
# day 393: buy 1 unit at price 1310.700000, total balance 8262.300000
# day 395, sell 1 unit at price 1334.700000, investment 1.831083 %, total balance 9597.000000,
# day 397: buy 1 unit at price 1334.000000, total balance 8263.000000
# day 398: buy 1 unit at price 1361.600000, total balance 6901.400000
# day 400: buy 1 unit at price 1366.200000, total balance 5535.200000
# day 401: buy 1 unit at price 1373.100000, total balance 4162.100000
# day 402: buy 1 unit at price 1370.600000, total balance 2791.500000
# day 403, sell 1 unit at price 1371.200000, investment 2.788606 %, total balance 4162.700000,
# day 404: buy 1 unit at price 1395.700000, total balance 2767.000000
# day 405, sell 1 unit at price 1393.000000, investment 2.306110 %, total balance 4160.000000,
# day 407, sell 1 unit at price 1419.000000, investment 3.864734 %, total balance 5579.000000,
# day 408, sell 1 unit at price 1412.900000, investment 2.898551 %, total balance 6991.900000,
# day 409, sell 1 unit at price 1396.100000, investment 1.860499 %, total balance 8388.000000,
# day 410: buy 1 unit at price 1393.700000, total balance 6994.300000
# day 413: buy 1 unit at price 1373.100000, total balance 5621.200000
# day 414: buy 1 unit at price 1386.700000, total balance 4234.500000
# day 415, sell 1 unit at price 1386.800000, investment -0.637673 %, total balance 5621.300000,
# day 416: buy 1 unit at price 1364.100000, total balance 4257.200000
# day 417: buy 1 unit at price 1363.900000, total balance 2893.300000
# day 418, sell 1 unit at price 1330.400000, investment -4.541867 %, total balance 4223.700000,
# day 419: buy 1 unit at price 1308.400000, total balance 2915.300000
# day 420: buy 1 unit at price 1317.900000, total balance 1597.400000
# day 421, sell 1 unit at price 1309.500000, investment -4.631855 %, total balance 2906.900000,
# day 422: buy 1 unit at price 1307.800000, total balance 1599.100000
# day 425, sell 1 unit at price 1326.900000, investment -4.312396 %, total balance 2926.000000,
# day 426: buy 1 unit at price 1316.000000, total balance 1610.000000
# day 427, sell 1 unit at price 1335.900000, investment -2.067297 %, total balance 2945.900000,
# day 428: buy 1 unit at price 1323.600000, total balance 1622.300000
# day 430, sell 1 unit at price 1326.500000, investment -2.742137 %, total balance 2948.800000,
# day 433, sell 1 unit at price 1317.400000, investment 0.687863 %, total balance 4266.200000,
# day 434, sell 1 unit at price 1309.700000, investment -0.622202 %, total balance 5575.900000,
# day 435, sell 1 unit at price 1324.800000, investment 1.299893 %, total balance 6900.700000,
# day 436: buy 1 unit at price 1324.200000, total balance 5576.500000
# day 437: buy 1 unit at price 1306.900000, total balance 4269.600000
# day 438, sell 1 unit at price 1296.600000, investment -1.474164 %, total balance 5566.200000,
# day 439, sell 1 unit at price 1268.000000, investment -4.200665 %, total balance 6834.200000,
# day 441: buy 1 unit at price 1273.000000, total balance 5561.200000
# day 442, sell 1 unit at price 1282.000000, investment -3.186830 %, total balance 6843.200000,
# day 443, sell 1 unit at price 1322.700000, investment 1.208968 %, total balance 8165.900000,
# day 445, sell 1 unit at price 1315.700000, investment 3.354281 %, total balance 9481.600000,
# day 449: buy 1 unit at price 1352.400000, total balance 8129.200000
# day 450: buy 1 unit at price 1352.000000, total balance 6777.200000
# day 452, sell 1 unit at price 1349.000000, investment -0.251405 %, total balance 8126.200000,
# day 453, sell 1 unit at price 1323.600000, investment -2.100592 %, total balance 9449.800000,
# day 462: buy 1 unit at price 1268.300000, total balance 8181.500000
# day 463: buy 1 unit at price 1286.200000, total balance 6895.300000
# day 465, sell 1 unit at price 1272.200000, investment 0.307498 %, total balance 8167.500000,
# day 467, sell 1 unit at price 1257.900000, investment -2.200280 %, total balance 9425.400000,
# day 471: buy 1 unit at price 1241.400000, total balance 8184.000000
# day 472, sell 1 unit at price 1237.800000, investment -0.289995 %, total balance 9421.800000,
# day 474: buy 1 unit at price 1250.600000, total balance 8171.200000
# day 475, sell 1 unit at price 1222.300000, investment -2.262914 %, total balance 9393.500000,
# day 477: buy 1 unit at price 1248.200000, total balance 8145.300000
# day 478, sell 1 unit at price 1233.200000, investment -1.201730 %, total balance 9378.500000,
# day 482: buy 1 unit at price 1258.500000, total balance 8120.000000
# day 483, sell 1 unit at price 1226.000000, investment -2.582439 %, total balance 9346.000000,
# day 486: buy 1 unit at price 1231.200000, total balance 8114.800000
# day 487, sell 1 unit at price 1236.100000, investment 0.397986 %, total balance 9350.900000,
# day 492: buy 1 unit at price 1214.100000, total balance 8136.800000
# day 494, sell 1 unit at price 1203.100000, investment -0.906021 %, total balance 9339.900000,
# day 497: buy 1 unit at price 1225.000000, total balance 8114.900000
# day 498: buy 1 unit at price 1238.400000, total balance 6876.500000
# day 499: buy 1 unit at price 1237.800000, total balance 5638.700000
# day 501, sell 1 unit at price 1225.300000, investment 0.024490 %, total balance 6864.000000,
# day 502: buy 1 unit at price 1229.300000, total balance 5634.700000
# day 503: buy 1 unit at price 1246.700000, total balance 4388.000000
# day 504, sell 1 unit at price 1250.900000, investment 1.009367 %, total balance 5638.900000,
# day 505, sell 1 unit at price 1245.200000, investment 0.597835 %, total balance 6884.100000,
# day 506: buy 1 unit at price 1238.100000, total balance 5646.000000
# day 507, sell 1 unit at price 1240.000000, investment 0.870414 %, total balance 6886.000000,
# day 509, sell 1 unit at price 1255.100000, investment 0.673779 %, total balance 8141.100000,
# day 510: buy 1 unit at price 1242.300000, total balance 6898.800000
# day 511, sell 1 unit at price 1239.000000, investment 0.072692 %, total balance 8137.800000,
# day 512: buy 1 unit at price 1262.600000, total balance 6875.200000
# day 513: buy 1 unit at price 1264.500000, total balance 5610.700000
# day 514, sell 1 unit at price 1263.600000, investment 1.714562 %, total balance 6874.300000,
# day 515: buy 1 unit at price 1251.000000, total balance 5623.300000
# day 516: buy 1 unit at price 1262.200000, total balance 4361.100000
# day 517: buy 1 unit at price 1242.200000, total balance 3118.900000
# day 519: buy 1 unit at price 1260.400000, total balance 1858.500000
# day 521: buy 1 unit at price 1257.300000, total balance 601.200000
# day 522, sell 1 unit at price 1257.600000, investment -0.396008 %, total balance 1858.800000,
# day 524, sell 1 unit at price 1274.800000, investment 0.814551 %, total balance 3133.600000,
# day 525, sell 1 unit at price 1290.100000, investment 3.125500 %, total balance 4423.700000,
# day 526: buy 1 unit at price 1295.300000, total balance 3128.400000
# day 529: buy 1 unit at price 1328.500000, total balance 1799.900000
# day 532, sell 1 unit at price 1317.100000, investment 4.349548 %, total balance 3117.000000,
# day 533: buy 1 unit at price 1323.900000, total balance 1793.100000
# day 535, sell 1 unit at price 1343.000000, investment 8.114635 %, total balance 3136.100000,
# day 536, sell 1 unit at price 1328.200000, investment 5.379245 %, total balance 4464.300000,
# day 537: buy 1 unit at price 1331.600000, total balance 3132.700000
# day 538: buy 1 unit at price 1321.400000, total balance 1811.300000
# day 539: buy 1 unit at price 1350.100000, total balance 461.200000
# day 541, sell 1 unit at price 1340.200000, investment 6.593494 %, total balance 1801.400000,
# day 544, sell 1 unit at price 1341.400000, investment 3.559021 %, total balance 3142.800000,
# day 545, sell 1 unit at price 1346.500000, investment 1.354912 %, total balance 4489.300000,
# day 547: buy 1 unit at price 1372.200000, total balance 3117.100000
# day 548: buy 1 unit at price 1379.000000, total balance 1738.100000
# day 549, sell 1 unit at price 1372.900000, investment 3.701186 %, total balance 3111.000000,
# day 551, sell 1 unit at price 1341.400000, investment 0.735957 %, total balance 4452.400000,
# day 552, sell 1 unit at price 1330.500000, investment 0.688664 %, total balance 5782.900000,
# day 553, sell 1 unit at price 1336.000000, investment -1.044367 %, total balance 7118.900000,
# day 554: buy 1 unit at price 1311.200000, total balance 5807.700000
# day 555, sell 1 unit at price 1311.400000, investment -4.430841 %, total balance 7119.100000,
# day 557, sell 1 unit at price 1294.700000, investment -6.113125 %, total balance 8413.800000,
# day 558: buy 1 unit at price 1293.800000, total balance 7120.000000
# day 559: buy 1 unit at price 1283.400000, total balance 5836.600000
# day 560, sell 1 unit at price 1279.600000, investment -2.410006 %, total balance 7116.200000,
# day 561: buy 1 unit at price 1290.500000, total balance 5825.700000
# day 562: buy 1 unit at price 1284.400000, total balance 4541.300000
# day 563, sell 1 unit at price 1303.200000, investment 0.726542 %, total balance 5844.500000,
# day 564: buy 1 unit at price 1298.000000, total balance 4546.500000
# day 565, sell 1 unit at price 1308.700000, investment 1.971326 %, total balance 5855.200000,
# day 566, sell 1 unit at price 1305.500000, investment 1.162340 %, total balance 7160.700000,
# day 567: buy 1 unit at price 1320.100000, total balance 5840.600000
# day 568: buy 1 unit at price 1318.700000, total balance 4521.900000
# day 569, sell 1 unit at price 1327.200000, investment 3.332295 %, total balance 5849.100000,
# day 570, sell 1 unit at price 1300.000000, investment 0.154083 %, total balance 7149.100000,
# day 576: buy 1 unit at price 1290.500000, total balance 5858.600000
# day 577, sell 1 unit at price 1300.700000, investment -1.469586 %, total balance 7159.300000,
# day 578: buy 1 unit at price 1298.900000, total balance 5860.400000
# day 579, sell 1 unit at price 1296.000000, investment -1.721392 %, total balance 7156.400000,
# day 580, sell 1 unit at price 1295.600000, investment 0.395196 %, total balance 8452.000000,
# day 581: buy 1 unit at price 1283.100000, total balance 7168.900000
# day 582, sell 1 unit at price 1302.600000, investment 0.284856 %, total balance 8471.500000,
# day 583, sell 1 unit at price 1309.000000, investment 2.018549 %, total balance 9780.500000,
# day 585: buy 1 unit at price 1288.600000, total balance 8491.900000
# day 586, sell 1 unit at price 1287.400000, investment -0.093124 %, total balance 9779.300000,
# day 588: buy 1 unit at price 1295.600000, total balance 8483.700000
# day 589, sell 1 unit at price 1294.600000, investment -0.077184 %, total balance 9778.300000,
# day 592: buy 1 unit at price 1293.300000, total balance 8485.000000
# day 593: buy 1 unit at price 1293.700000, total balance 7191.300000
# day 594, sell 1 unit at price 1294.500000, investment 0.092786 %, total balance 8485.800000,
# day 595: buy 1 unit at price 1288.000000, total balance 7197.800000
# day 596: buy 1 unit at price 1294.900000, total balance 5902.900000
# day 597: buy 1 unit at price 1291.600000, total balance 4611.300000
# day 599, sell 1 unit at price 1292.500000, investment -0.092757 %, total balance 5903.800000,
# day 601, sell 1 unit at price 1259.300000, investment -2.228261 %, total balance 7163.100000,
# day 602, sell 1 unit at price 1256.300000, investment -2.980925 %, total balance 8419.400000,
# day 603: buy 1 unit at price 1245.600000, total balance 7173.800000
# day 604, sell 1 unit at price 1243.700000, investment -3.708579 %, total balance 8417.500000,
# day 605, sell 1 unit at price 1244.300000, investment -0.104367 %, total balance 9661.800000,
# day 609: buy 1 unit at price 1253.500000, total balance 8408.300000
# day 610: buy 1 unit at price 1259.800000, total balance 7148.500000
# day 611, sell 1 unit at price 1260.800000, investment 0.582369 %, total balance 8409.300000,
# day 614, sell 1 unit at price 1274.900000, investment 1.198603 %, total balance 9684.200000,
# day 616: buy 1 unit at price 1272.400000, total balance 8411.800000
# day 618: buy 1 unit at price 1316.200000, total balance 7095.600000
# day 619: buy 1 unit at price 1318.000000, total balance 5777.600000
# day 620, sell 1 unit at price 1320.900000, investment 3.811694 %, total balance 7098.500000,
# day 622, sell 1 unit at price 1316.100000, investment -0.007598 %, total balance 8414.600000,
# day 624: buy 1 unit at price 1475.100000, total balance 6939.500000
# day 626: buy 1 unit at price 1484.800000, total balance 5454.700000
# day 627: buy 1 unit at price 1475.600000, total balance 3979.100000
# day 629: buy 1 unit at price 1472.000000, total balance 2507.100000
# day 630: buy 1 unit at price 1471.400000, total balance 1035.700000
# day 633, sell 1 unit at price 1492.900000, investment 13.270106 %, total balance 2528.600000,
# day 634: buy 1 unit at price 1460.700000, total balance 1067.900000
# day 636, sell 1 unit at price 1454.900000, investment -1.369399 %, total balance 2522.800000,
# day 638: buy 1 unit at price 1464.700000, total balance 1058.100000
# day 639, sell 1 unit at price 1469.600000, investment -1.023707 %, total balance 2527.700000,
# day 640: buy 1 unit at price 1461.600000, total balance 1066.100000
# day 642, sell 1 unit at price 1447.300000, investment -1.917864 %, total balance 2513.400000,
# day 643, sell 1 unit at price 1460.300000, investment -0.794837 %, total balance 3973.700000,
# day 644: buy 1 unit at price 1462.000000, total balance 2511.700000
# day 645: buy 1 unit at price 1456.700000, total balance 1055.000000
# day 647, sell 1 unit at price 1441.500000, investment -2.032078 %, total balance 2496.500000,
# day 649, sell 1 unit at price 1441.900000, investment -1.287054 %, total balance 3938.400000,
# day 651, sell 1 unit at price 1462.700000, investment -0.136547 %, total balance 5401.100000,
# day 652: buy 1 unit at price 1467.300000, total balance 3933.800000
# day 653, sell 1 unit at price 1465.900000, investment 0.294198 %, total balance 5399.700000,
# day 654: buy 1 unit at price 1465.500000, total balance 3934.200000
# day 655, sell 1 unit at price 1465.300000, investment 0.225718 %, total balance 5399.500000,
# day 656, sell 1 unit at price 1467.900000, investment 0.768861 %, total balance 6867.400000,
# day 659: buy 1 unit at price 1452.800000, total balance 5414.600000
# day 660, sell 1 unit at price 1449.000000, investment -1.247189 %, total balance 6863.600000,
# day 661, sell 1 unit at price 1449.000000, investment -1.125896 %, total balance 8312.600000,
# day 662, sell 1 unit at price 1429.200000, investment -1.624449 %, total balance 9741.800000,
# day 664: buy 1 unit at price 1433.100000, total balance 8308.700000
# day 665: buy 1 unit at price 1439.300000, total balance 6869.400000
# day 666, sell 1 unit at price 1436.900000, investment 0.265159 %, total balance 8306.300000,
# day 667, sell 1 unit at price 1443.800000, investment 0.312652 %, total balance 9750.100000,
# day 671: buy 1 unit at price 1419.000000, total balance 8331.100000
# day 674, sell 1 unit at price 1423.200000, investment 0.295983 %, total balance 9754.300000,
# day 678: buy 1 unit at price 1395.400000, total balance 8358.900000
# day 679: buy 1 unit at price 1387.800000, total balance 6971.100000
# day 680, sell 1 unit at price 1391.300000, investment -0.293823 %, total balance 8362.400000,
# day 681, sell 1 unit at price 1393.000000, investment 0.374694 %, total balance 9755.400000,
# day 682: buy 1 unit at price 1392.000000, total balance 8363.400000
# day 685, sell 1 unit at price 1374.200000, investment -1.278736 %, total balance 9737.600000,
# day 696: buy 1 unit at price 1363.600000, total balance 8374.000000
# day 697: buy 1 unit at price 1344.200000, total balance 7029.800000
# day 698, sell 1 unit at price 1358.800000, investment -0.352009 %, total balance 8388.600000,
# day 700, sell 1 unit at price 1229.300000, investment -8.547835 %, total balance 9617.900000,
# day 702: buy 1 unit at price 1361.300000, total balance 8256.600000
# day 703: buy 1 unit at price 1357.500000, total balance 6899.100000
# day 706: buy 1 unit at price 1371.800000, total balance 5527.300000
# day 707, sell 1 unit at price 1366.600000, investment 0.389334 %, total balance 6893.900000,
# day 709: buy 1 unit at price 1355.000000, total balance 5538.900000
# day 710, sell 1 unit at price 1352.400000, investment -0.375691 %, total balance 6891.300000,
# day 712: buy 1 unit at price 1349.200000, total balance 5542.100000
# day 713, sell 1 unit at price 1322.900000, investment -3.564660 %, total balance 6865.000000,
# day 714: buy 1 unit at price 1295.900000, total balance 5569.100000
# day 715, sell 1 unit at price 1294.400000, investment -4.472325 %, total balance 6863.500000,
# day 717, sell 1 unit at price 1268.100000, investment -6.010969 %, total balance 8131.600000,
# day 719, sell 1 unit at price 1291.000000, investment -0.378116 %, total balance 9422.600000,
# day 720: buy 1 unit at price 1281.300000, total balance 8141.300000
# day 721, sell 1 unit at price 1285.100000, investment 0.296574 %, total balance 9426.400000,
# day 731: buy 1 unit at price 1315.200000, total balance 8111.200000
# day 732, sell 1 unit at price 1314.500000, investment -0.053224 %, total balance 9425.700000,
# day 735: buy 1 unit at price 1332.500000, total balance 8093.200000
# day 737, sell 1 unit at price 1325.800000, investment -0.502814 %, total balance 9419.000000,
# day 739: buy 1 unit at price 1310.800000, total balance 8108.200000
# day 741, sell 1 unit at price 1350.200000, investment 3.005798 %, total balance 9458.400000,
# day 742: buy 1 unit at price 1345.500000, total balance 8112.900000
# day 743: buy 1 unit at price 1342.300000, total balance 6770.600000
# day 744, sell 1 unit at price 1333.500000, investment -0.891862 %, total balance 8104.100000,
# day 745: buy 1 unit at price 1317.700000, total balance 6786.400000
# day 747: buy 1 unit at price 1302.300000, total balance 5484.100000
# day 748, sell 1 unit at price 1303.900000, investment -2.860761 %, total balance 6788.000000,
# day 751: buy 1 unit at price 1289.700000, total balance 5498.300000
# day 752: buy 1 unit at price 1285.600000, total balance 4212.700000
# day 754: buy 1 unit at price 1307.700000, total balance 2905.000000
# day 757: buy 1 unit at price 1335.400000, total balance 1569.600000
# day 759, sell 1 unit at price 1337.700000, investment 1.517796 %, total balance 2907.300000,
# day 760: buy 1 unit at price 1353.500000, total balance 1553.800000
# day 761: buy 1 unit at price 1362.200000, total balance 191.600000
# day 763, sell 1 unit at price 1351.600000, investment 3.785610 %, total balance 1543.200000,
# day 764, sell 1 unit at price 1357.400000, investment 5.249283 %, total balance 2900.600000,
# day 766, sell 1 unit at price 1374.500000, investment 6.915059 %, total balance 4275.100000,
# day 768, sell 1 unit at price 1392.800000, investment 6.507609 %, total balance 5667.900000,
# day 769, sell 1 unit at price 1404.900000, investment 5.204433 %, total balance 7072.800000,
# day 772, sell 1 unit at price 1412.400000, investment 4.351681 %, total balance 8485.200000,
# day 773: buy 1 unit at price 1413.400000, total balance 7071.800000
# day 774, sell 1 unit at price 1425.200000, investment 4.624872 %, total balance 8497.000000,
# day 776, sell 1 unit at price 1405.600000, investment -0.551861 %, total balance 9902.600000,
# day 782: buy 1 unit at price 1367.300000, total balance 8535.300000
# day 783, sell 1 unit at price 1373.400000, investment 0.446135 %, total balance 9908.700000,
# day 784: buy 1 unit at price 1354.900000, total balance 8553.800000
# day 785, sell 1 unit at price 1332.600000, investment -1.645878 %, total balance 9886.400000,
# day 787: buy 1 unit at price 1331.200000, total balance 8555.200000
# day 788, sell 1 unit at price 1319.200000, investment -0.901442 %, total balance 9874.400000,
# day 793: buy 1 unit at price 1309.900000, total balance 8564.500000
# day 794: buy 1 unit at price 1301.500000, total balance 7263.000000
# day 796, sell 1 unit at price 1303.200000, investment -0.511489 %, total balance 8566.200000,
# day 797, sell 1 unit at price 1298.700000, investment -0.215136 %, total balance 9864.900000,
# day 799: buy 1 unit at price 1296.000000, total balance 8568.900000
# day 801: buy 1 unit at price 1309.400000, total balance 7259.500000
# day 802, sell 1 unit at price 1305.800000, investment 0.756173 %, total balance 8565.300000,
# day 803, sell 1 unit at price 1304.200000, investment -0.397128 %, total balance 9869.500000,
# day 808: buy 1 unit at price 1258.100000, total balance 8611.400000
# day 809, sell 1 unit at price 1248.400000, investment -0.771004 %, total balance 9859.800000,
# day 810: buy 1 unit at price 1249.000000, total balance 8610.800000
# day 811, sell 1 unit at price 1248.900000, investment -0.008006 %, total balance 9859.700000,
# day 818: buy 1 unit at price 1281.200000, total balance 8578.500000
# day 819, sell 1 unit at price 1287.300000, investment 0.476116 %, total balance 9865.800000,
# day 831: buy 1 unit at price 1293.300000, total balance 8572.500000
# day 832, sell 1 unit at price 1287.800000, investment -0.425269 %, total balance 9860.300000,
# day 833: buy 1 unit at price 1278.100000, total balance 8582.200000
# day 834: buy 1 unit at price 1286.500000, total balance 7295.700000
# day 837, sell 1 unit at price 1279.300000, investment 0.093889 %, total balance 8575.000000,
# day 839: buy 1 unit at price 1274.700000, total balance 7300.300000
# day 840, sell 1 unit at price 1282.000000, investment -0.349786 %, total balance 8582.300000,
# day 842, sell 1 unit at price 1289.200000, investment 1.137523 %, total balance 9871.500000,
# day 847: buy 1 unit at price 1279.000000, total balance 8592.500000
# day 848: buy 1 unit at price 1288.200000, total balance 7304.300000
# day 850: buy 1 unit at price 1278.500000, total balance 6025.800000
# day 852: buy 1 unit at price 1277.300000, total balance 4748.500000
# day 854, sell 1 unit at price 1312.200000, investment 2.595778 %, total balance 6060.700000,
# day 855: buy 1 unit at price 1319.000000, total balance 4741.700000
# day 856: buy 1 unit at price 1318.900000, total balance 3422.800000
# day 857, sell 1 unit at price 1321.200000, investment 2.561714 %, total balance 4744.000000,
# day 858: buy 1 unit at price 1301.400000, total balance 3442.600000
# day 861: buy 1 unit at price 1299.700000, total balance 2142.900000
# day 862: buy 1 unit at price 1204.400000, total balance 938.500000
# day 863, sell 1 unit at price 1207.400000, investment -5.561205 %, total balance 2145.900000,
# day 864: buy 1 unit at price 1282.200000, total balance 863.700000
# day 865, sell 1 unit at price 1278.600000, investment 0.101777 %, total balance 2142.300000,
# day 866, sell 1 unit at price 1280.500000, investment -2.918878 %, total balance 3422.800000,
# day 867, sell 1 unit at price 1280.700000, investment -2.896353 %, total balance 4703.500000,
# day 868, sell 1 unit at price 1280.400000, investment -1.613647 %, total balance 5983.900000,
# day 870: buy 1 unit at price 1279.900000, total balance 4704.000000
# day 871: buy 1 unit at price 1270.100000, total balance 3433.900000
# day 872: buy 1 unit at price 1266.600000, total balance 2167.300000
# day 873, sell 1 unit at price 1272.000000, investment -2.131261 %, total balance 3439.300000,
# day 874, sell 1 unit at price 1276.800000, investment 6.011292 %, total balance 4716.100000,
# day 875: buy 1 unit at price 1288.600000, total balance 3427.500000
# day 877, sell 1 unit at price 1281.000000, investment -0.093589 %, total balance 4708.500000,
# day 878, sell 1 unit at price 1285.800000, investment 0.460974 %, total balance 5994.300000,
# day 879, sell 1 unit at price 1279.400000, investment 0.732226 %, total balance 7273.700000,
# day 880, sell 1 unit at price 1276.900000, investment 0.813201 %, total balance 8550.600000,
# day 881: buy 1 unit at price 1300.800000, total balance 7249.800000
# day 883, sell 1 unit at price 1282.100000, investment -0.504423 %, total balance 8531.900000,
# day 885: buy 1 unit at price 1271.000000, total balance 7260.900000
# day 888, sell 1 unit at price 1278.000000, investment -1.752768 %, total balance 8538.900000,
# day 889: buy 1 unit at price 1270.800000, total balance 7268.100000
# day 890: buy 1 unit at price 1268.500000, total balance 5999.600000
# day 891: buy 1 unit at price 1261.500000, total balance 4738.100000
# day 894: buy 1 unit at price 1249.500000, total balance 3488.600000
# day 895: buy 1 unit at price 1258.600000, total balance 2230.000000
# day 896: buy 1 unit at price 1255.100000, total balance 974.900000
# day 897, sell 1 unit at price 1256.600000, investment -1.132966 %, total balance 2231.500000,
# day 898, sell 1 unit at price 1255.000000, investment -1.243311 %, total balance 3486.500000,
# day 899: buy 1 unit at price 1252.400000, total balance 2234.100000
# day 900, sell 1 unit at price 1246.300000, investment -1.750099 %, total balance 3480.400000,
# day 901: buy 1 unit at price 1243.200000, total balance 2237.200000
# day 902, sell 1 unit at price 1230.700000, investment -2.441538 %, total balance 3467.900000,
# day 903: buy 1 unit at price 1205.500000, total balance 2262.400000
# day 906: buy 1 unit at price 1190.100000, total balance 1072.300000
# day 907, sell 1 unit at price 1180.000000, investment -5.562225 %, total balance 2252.300000,
# day 908, sell 1 unit at price 1190.600000, investment -5.402829 %, total balance 3442.900000,
# day 911: buy 1 unit at price 1183.400000, total balance 2259.500000
# day 912, sell 1 unit at price 1183.100000, investment -5.736595 %, total balance 3442.600000,
# day 913, sell 1 unit at price 1176.800000, investment -6.036410 %, total balance 4619.400000,
# day 914: buy 1 unit at price 1178.700000, total balance 3440.700000
# day 915, sell 1 unit at price 1177.100000, investment -5.316924 %, total balance 4617.800000,
# day 916, sell 1 unit at price 1181.600000, investment -1.982580 %, total balance 5799.400000,
# day 918: buy 1 unit at price 1195.800000, total balance 4603.600000
# day 919: buy 1 unit at price 1197.700000, total balance 3405.900000
# day 920, sell 1 unit at price 1213.000000, investment 1.924208 %, total balance 4618.900000,
# day 925, sell 1 unit at price 1217.100000, investment 2.847727 %, total balance 5836.000000,
# day 926: buy 1 unit at price 1242.200000, total balance 4593.800000
# day 927: buy 1 unit at price 1246.800000, total balance 3347.000000
# day 928: buy 1 unit at price 1238.900000, total balance 2108.100000
# day 930: buy 1 unit at price 1209.000000, total balance 899.100000
# day 931, sell 1 unit at price 1207.200000, investment 2.417918 %, total balance 2106.300000,
# day 932, sell 1 unit at price 1218.400000, investment 1.889948 %, total balance 3324.700000,
# day 933, sell 1 unit at price 1216.900000, investment 1.603073 %, total balance 4541.600000,
# day 934, sell 1 unit at price 1221.300000, investment -1.682499 %, total balance 5762.900000,
# day 935: buy 1 unit at price 1214.400000, total balance 4548.500000
# day 936: buy 1 unit at price 1203.500000, total balance 3345.000000
# day 937: buy 1 unit at price 1200.500000, total balance 2144.500000
# day 938: buy 1 unit at price 1119.900000, total balance 1024.600000
# day 939, sell 1 unit at price 1119.900000, investment -10.178056 %, total balance 2144.500000,
# day 942, sell 1 unit at price 1187.900000, investment -4.116555 %, total balance 3332.400000,
# day 945, sell 1 unit at price 1180.500000, investment -2.357320 %, total balance 4512.900000,
# day 946, sell 1 unit at price 1196.300000, investment -1.490448 %, total balance 5709.200000,
# day 948: buy 1 unit at price 1214.100000, total balance 4495.100000
# day 949, sell 1 unit at price 1209.400000, investment 0.490237 %, total balance 5704.500000,
# day 950, sell 1 unit at price 1199.600000, investment -0.074969 %, total balance 6904.100000,
# day 952: buy 1 unit at price 1226.900000, total balance 5677.200000
# day 954: buy 1 unit at price 1204.400000, total balance 4472.800000
# day 955: buy 1 unit at price 1199.100000, total balance 3273.700000
# day 956, sell 1 unit at price 1183.600000, investment 5.688008 %, total balance 4457.300000,
# day 958: buy 1 unit at price 1204.200000, total balance 3253.100000
# day 959, sell 1 unit at price 1203.500000, investment -0.873075 %, total balance 4456.600000,
# day 960: buy 1 unit at price 1211.300000, total balance 3245.300000
# day 961: buy 1 unit at price 1214.000000, total balance 2031.300000
# day 962: buy 1 unit at price 1209.900000, total balance 821.400000
# day 963, sell 1 unit at price 1222.400000, investment -0.366778 %, total balance 2043.800000,
# day 964, sell 1 unit at price 1231.100000, investment 2.216871 %, total balance 3274.900000,
# day 965: buy 1 unit at price 1231.700000, total balance 2043.200000
# day 966: buy 1 unit at price 1243.600000, total balance 799.600000
# day 967, sell 1 unit at price 1251.400000, investment 4.361605 %, total balance 2051.000000,
# day 968, sell 1 unit at price 1246.600000, investment 3.521010 %, total balance 3297.600000,
# day 969: buy 1 unit at price 1236.300000, total balance 2061.300000
# day 971, sell 1 unit at price 1229.700000, investment 1.519029 %, total balance 3291.000000,
# day 972, sell 1 unit at price 1228.200000, investment 1.169687 %, total balance 4519.200000,
# day 973, sell 1 unit at price 1218.700000, investment 0.727333 %, total balance 5737.900000,
# day 974, sell 1 unit at price 1220.300000, investment -0.925550 %, total balance 6958.200000,
# day 976, sell 1 unit at price 1229.300000, investment -1.149887 %, total balance 8187.500000,
# day 977, sell 1 unit at price 1201.800000, investment -2.790585 %, total balance 9389.300000,
# day 979: buy 1 unit at price 1190.400000, total balance 8198.900000
# day 981, sell 1 unit at price 1161.200000, investment -2.452957 %, total balance 9360.100000,
# day 982: buy 1 unit at price 1160.100000, total balance 8200.000000
# day 983, sell 1 unit at price 1147.900000, investment -1.051633 %, total balance 9347.900000,
# day 984: buy 1 unit at price 1149.200000, total balance 8198.700000
# day 985, sell 1 unit at price 1149.400000, investment 0.017403 %, total balance 9348.100000,
# day 986: buy 1 unit at price 1145.400000, total balance 8202.700000
# day 988, sell 1 unit at price 1141.300000, investment -0.357954 %, total balance 9344.000000,
# day 995: buy 1 unit at price 1131.600000, total balance 8212.400000
# ...
# day 1981, sell 1 unit at price 1549.200000, investment 0.957967 %, total balance 8826.830000,
# day 1982, sell 1 unit at price 1537.200000, investment -0.227169 %, total balance 10364.030000,
# day 1983: buy 1 unit at price 1541.300000, total balance 8822.730000
# day 1986, sell 1 unit at price 1563.500000, investment 1.440343 %, total balance 10386.230000,
# day 1987: buy 1 unit at price 1563.100000, total balance 8823.130000
# day 1988: buy 1 unit at price 1578.000000, total balance 7245.130000
# day 1989: buy 1 unit at price 1575.300000, total balance 5669.830000
# day 1992: buy 1 unit at price 1538.050000, total balance 4131.780000
# day 1993: buy 1 unit at price 1535.150000, total balance 2596.630000
# day 1994: buy 1 unit at price 1583.200000, total balance 1013.430000
# day 1996, sell 1 unit at price 1552.900000, investment -0.652549 %, total balance 2566.330000,
# day 1997, sell 1 unit at price 1543.300000, investment -2.198986 %, total balance 4109.630000,
# day 1998, sell 1 unit at price 1539.600000, investment -2.266235 %, total balance 5649.230000,
# day 1999: buy 1 unit at price 1528.100000, total balance 4121.130000
# day 2001, sell 1 unit at price 1537.800000, investment -0.016254 %, total balance 5658.930000,
# day 2002, sell 1 unit at price 1530.700000, investment -0.289874 %, total balance 7189.630000,
# day 2004: buy 1 unit at price 1544.100000, total balance 5645.530000
# day 2005, sell 1 unit at price 1546.100000, investment -2.343355 %, total balance 7191.630000,
# day 2006, sell 1 unit at price 1536.400000, investment 0.543158 %, total balance 8728.030000,
# day 2007: buy 1 unit at price 1545.300000, total balance 7182.730000
# day 2008: buy 1 unit at price 1561.600000, total balance 5621.130000
# day 2009, sell 1 unit at price 1570.100000, investment 1.683829 %, total balance 7191.230000,
# day 2010, sell 1 unit at price 1542.000000, investment -0.213551 %, total balance 8733.230000,
# day 2012, sell 1 unit at price 1536.100000, investment -1.632941 %, total balance 10269.330000,
# day 2013: buy 1 unit at price 1502.300000, total balance 8767.030000
# day 2014, sell 1 unit at price 1518.000000, investment 1.045064 %, total balance 10285.030000,
# day 2015: buy 1 unit at price 1536.800000, total balance 8748.230000
# day 2016, sell 1 unit at price 1541.300000, investment 0.292816 %, total balance 10289.530000,
# day 2020: buy 1 unit at price 1541.100000, total balance 8748.430000
# day 2021: buy 1 unit at price 1529.700000, total balance 7218.730000
# day 2022: buy 1 unit at price 1517.800000, total balance 5700.930000
# day 2023, sell 1 unit at price 1527.100000, investment -0.908442 %, total balance 7228.030000,
# day 2025: buy 1 unit at price 1523.400000, total balance 5704.630000
# day 2027: buy 1 unit at price 1523.000000, total balance 4181.630000
# day 2028, sell 1 unit at price 1517.300000, investment -0.810616 %, total balance 5698.930000,
# day 2029, sell 1 unit at price 1516.600000, investment -0.079062 %, total balance 7215.530000,
# day 2031, sell 1 unit at price 1533.900000, investment 0.689248 %, total balance 8749.430000,
# day 2032, sell 1 unit at price 1535.100000, investment 0.794485 %, total balance 10284.530000,
# day 2036: buy 1 unit at price 1544.000000, total balance 8740.530000
# day 2037: buy 1 unit at price 1541.300000, total balance 7199.230000
# day 2039: buy 1 unit at price 1514.500000, total balance 5684.730000
# day 2040, sell 1 unit at price 1523.900000, investment -1.301813 %, total balance 7208.630000,
# day 2041, sell 1 unit at price 1497.700000, investment -2.828781 %, total balance 8706.330000,
# day 2042, sell 1 unit at price 1496.300000, investment -1.201717 %, total balance 10202.630000,
# day 2044: buy 1 unit at price 1484.200000, total balance 8718.430000
# day 2045, sell 1 unit at price 1493.900000, investment 0.653551 %, total balance 10212.330000,
# day 2048: buy 1 unit at price 1502.400000, total balance 8709.930000
# day 2049: buy 1 unit at price 1504.800000, total balance 7205.130000
# day 2052, sell 1 unit at price 1494.400000, investment -0.532481 %, total balance 8699.530000,
# day 2053, sell 1 unit at price 1488.100000, investment -1.109782 %, total balance 10187.630000,
# day 2057: buy 1 unit at price 1496.600000, total balance 8691.030000
# day 2059, sell 1 unit at price 1508.600000, investment 0.801817 %, total balance 10199.630000,
# day 2064: buy 1 unit at price 1493.200000, total balance 8706.430000
# day 2065: buy 1 unit at price 1500.100000, total balance 7206.330000
# day 2066, sell 1 unit at price 1497.500000, investment 0.287972 %, total balance 8703.830000,
# day 2067, sell 1 unit at price 1506.900000, investment 0.453303 %, total balance 10210.730000,
# day 2068: buy 1 unit at price 1506.700000, total balance 8704.030000
# day 2069: buy 1 unit at price 1506.800000, total balance 7197.230000
# day 2070, sell 1 unit at price 1504.300000, investment -0.159289 %, total balance 8701.530000,
# day 2071, sell 1 unit at price 1510.000000, investment 0.212371 %, total balance 10211.530000,
# day 2072: buy 1 unit at price 1506.400000, total balance 8705.130000
# day 2073, sell 1 unit at price 1514.400000, investment 0.531067 %, total balance 10219.530000,
# day 2074: buy 1 unit at price 1530.500000, total balance 8689.030000
# day 2076, sell 1 unit at price 1540.300000, investment 0.640314 %, total balance 10229.330000,
# day 2078: buy 1 unit at price 1545.400000, total balance 8683.930000
# day 2079, sell 1 unit at price 1550.600000, investment 0.336482 %, total balance 10234.530000,
# day 2081: buy 1 unit at price 1555.200000, total balance 8679.330000
# day 2082: buy 1 unit at price 1579.600000, total balance 7099.730000
# day 2083, sell 1 unit at price 1596.100000, investment 2.629887 %, total balance 8695.830000,
# day 2085, sell 1 unit at price 1587.000000, investment 0.468473 %, total balance 10282.830000,
# day 2086: buy 1 unit at price 1581.400000, total balance 8701.430000
# day 2088: buy 1 unit at price 1577.500000, total balance 7123.930000
# day 2090, sell 1 unit at price 1580.300000, investment -0.069559 %, total balance 8704.230000,
# day 2091, sell 1 unit at price 1576.900000, investment -0.038035 %, total balance 10281.130000,
# day 2092: buy 1 unit at price 1587.200000, total balance 8693.930000
# day 2094, sell 1 unit at price 1561.250000, investment -1.634955 %, total balance 10255.180000,
# day 2098: buy 1 unit at price 1599.000000, total balance 8656.180000
# day 2099, sell 1 unit at price 1604.600000, investment 0.350219 %, total balance 10260.780000,
# day 2100: buy 1 unit at price 1596.900000, total balance 8663.880000
# day 2101, sell 1 unit at price 1597.900000, investment 0.062621 %, total balance 10261.780000,
# day 2103: buy 1 unit at price 1609.400000, total balance 8652.380000
# day 2104: buy 1 unit at price 1604.000000, total balance 7048.380000
# day 2109, sell 1 unit at price 1600.700000, investment -0.540574 %, total balance 8649.080000,
# day 2110: buy 1 unit at price 1591.100000, total balance 7057.980000
# day 2111: buy 1 unit at price 1592.400000, total balance 5465.580000
# day 2112: buy 1 unit at price 1599.600000, total balance 3865.980000
# day 2113, sell 1 unit at price 1606.900000, investment 0.180798 %, total balance 5472.880000,
# day 2114: buy 1 unit at price 1586.250000, total balance 3886.630000
# day 2115, sell 1 unit at price 1587.050000, investment -0.254541 %, total balance 5473.680000,
# day 2116, sell 1 unit at price 1624.000000, investment 1.984426 %, total balance 7097.680000,
# day 2117: buy 1 unit at price 1632.200000, total balance 5465.480000
# day 2118, sell 1 unit at price 1640.800000, investment 2.575644 %, total balance 7106.280000,
# day 2119, sell 1 unit at price 1669.100000, investment 5.223010 %, total balance 8775.380000,
# day 2120: buy 1 unit at price 1697.100000, total balance 7078.280000
# day 2121: buy 1 unit at price 1670.200000, total balance 5408.080000
# day 2122, sell 1 unit at price 1662.900000, investment 1.880897 %, total balance 7070.980000,
# day 2123, sell 1 unit at price 1661.400000, investment -2.103588 %, total balance 8732.380000,
# day 2124: buy 1 unit at price 1583.600000, total balance 7148.780000
# day 2126, sell 1 unit at price 1658.800000, investment -0.682553 %, total balance 8807.580000,
# day 2127: buy 1 unit at price 1656.500000, total balance 7151.080000
# day 2129, sell 1 unit at price 1683.000000, investment 6.276838 %, total balance 8834.080000,
# day 2130: buy 1 unit at price 1684.100000, total balance 7149.980000
# day 2132, sell 1 unit at price 1650.800000, investment -0.344099 %, total balance 8800.780000,
# day 2133, sell 1 unit at price 1598.800000, investment -5.065020 %, total balance 10399.580000,
# day 2136: buy 1 unit at price 1534.100000, total balance 8865.480000
# day 2137: buy 1 unit at price 1487.100000, total balance 7378.380000
# day 2138, sell 1 unit at price 1489.400000, investment -2.913761 %, total balance 8867.780000,
# day 2139, sell 1 unit at price 1495.100000, investment 0.537960 %, total balance 10362.880000,
# day 2142: buy 1 unit at price 1633.300000, total balance 8729.580000
# day 2143: buy 1 unit at price 1662.000000, total balance 7067.580000
# day 2145, sell 1 unit at price 1644.100000, investment 0.661238 %, total balance 8711.680000,
# day 2146, sell 1 unit at price 1597.600000, investment -3.874850 %, total balance 10309.280000,
# day 2147: buy 1 unit at price 1592.500000, total balance 8716.780000
# day 2148: buy 1 unit at price 1638.900000, total balance 7077.880000
# day 2149, sell 1 unit at price 1646.500000, investment 3.390895 %, total balance 8724.380000,
# day 2150, sell 1 unit at price 1693.100000, investment 3.307096 %, total balance 10417.480000,
# day 2151: buy 1 unit at price 1683.700000, total balance 8733.780000
# day 2152, sell 1 unit at price 1684.100000, investment 0.023757 %, total balance 10417.880000,
# day 2153: buy 1 unit at price 1753.600000, total balance 8664.280000
# day 2155, sell 1 unit at price 1762.700000, investment 0.518932 %, total balance 10426.980000,
# day 2156: buy 1 unit at price 1771.200000, total balance 8655.780000
# day 2157: buy 1 unit at price 1744.700000, total balance 6911.080000
# day 2158: buy 1 unit at price 1736.300000, total balance 5174.780000
# day 2159: buy 1 unit at price 1702.700000, total balance 3472.080000
# day 2160: buy 1 unit at price 1715.300000, total balance 1756.780000
# day 2161, sell 1 unit at price 1692.100000, investment -4.465899 %, total balance 3448.880000,
# day 2162, sell 1 unit at price 1743.500000, investment -0.068780 %, total balance 5192.380000,
# day 2163, sell 1 unit at price 1751.000000, investment 0.846628 %, total balance 6943.380000,
# day 2164, sell 1 unit at price 1741.700000, investment 2.290480 %, total balance 8685.080000,
# day 2165: buy 1 unit at price 1731.400000, total balance 6953.680000
# day 2166, sell 1 unit at price 1731.200000, investment 0.926952 %, total balance 8684.880000,
# day 2168: buy 1 unit at price 1704.900000, total balance 6979.980000
# day 2169, sell 1 unit at price 1712.000000, investment -1.120481 %, total balance 8691.980000,
# day 2170: buy 1 unit at price 1725.900000, total balance 6966.080000
# day 2171: buy 1 unit at price 1728.000000, total balance 5238.080000
# day 2173, sell 1 unit at price 1743.700000, investment 2.275793 %, total balance 6981.780000,
# day 2175: buy 1 unit at price 1720.900000, total balance 5260.880000
# day 2176: buy 1 unit at price 1728.000000, total balance 3532.880000
# day 2177, sell 1 unit at price 1737.300000, investment 0.660525 %, total balance 5270.180000,
# day 2178, sell 1 unit at price 1762.000000, investment 1.967593 %, total balance 7032.180000,
# day 2182: buy 1 unit at price 1781.700000, total balance 5250.480000
# day 2187, sell 1 unit at price 1740.500000, investment 1.138939 %, total balance 6990.980000,
# day 2188, sell 1 unit at price 1740.500000, investment 0.723380 %, total balance 8731.480000,
# day 2189, sell 1 unit at price 1742.700000, investment -2.188921 %, total balance 10474.180000,
# day 2190: buy 1 unit at price 1765.700000, total balance 8708.480000
# day 2192, sell 1 unit at price 1749.700000, investment -0.906156 %, total balance 10458.180000,
# day 2195: buy 1 unit at price 1701.900000, total balance 8756.280000
# day 2196: buy 1 unit at price 1723.800000, total balance 7032.480000
# day 2197, sell 1 unit at price 1740.300000, investment 2.256302 %, total balance 8772.780000,
# day 2198: buy 1 unit at price 1739.000000, total balance 7033.780000
# day 2200, sell 1 unit at price 1755.200000, investment 1.821557 %, total balance 8788.980000,
# day 2201, sell 1 unit at price 1744.900000, investment 0.339275 %, total balance 10533.880000,
# day 2208: buy 1 unit at price 1792.600000, total balance 8741.280000
# day 2209, sell 1 unit at price 1788.400000, investment -0.234297 %, total balance 10529.680000,
# day 2215: buy 1 unit at price 1787.600000, total balance 8742.080000
# day 2218, sell 1 unit at price 1850.600000, investment 3.524278 %, total balance 10592.680000,
# day 2219: buy 1 unit at price 1833.500000, total balance 8759.180000
# day 2220, sell 1 unit at price 1831.300000, investment -0.119989 %, total balance 10590.480000,
# day 2221: buy 1 unit at price 1843.700000, total balance 8746.780000
# day 2222: buy 1 unit at price 1841.500000, total balance 6905.280000
# day 2224, sell 1 unit at price 1826.500000, investment -0.932907 %, total balance 8731.780000,
# day 2225, sell 1 unit at price 1833.700000, investment -0.423568 %, total balance 10565.480000,
# day 2228: buy 1 unit at price 1892.600000, total balance 8672.880000
# day 2230: buy 1 unit at price 1925.200000, total balance 6747.680000
# day 2231, sell 1 unit at price 1955.400000, investment 3.318187 %, total balance 8703.080000,
# day 2233, sell 1 unit at price 1976.700000, investment 2.675047 %, total balance 10679.780000,
# day 2234: buy 1 unit at price 1966.800000, total balance 8712.980000
# day 2235: buy 1 unit at price 1985.900000, total balance 6727.080000
# day 2236: buy 1 unit at price 1986.300000, total balance 4740.780000
# day 2237: buy 1 unit at price 2021.000000, total balance 2719.780000
# day 2238: buy 1 unit at price 2049.300000, total balance 670.480000
# day 2246, sell 1 unit at price 1998.700000, investment 1.621924 %, total balance 2669.180000,
# day 2248, sell 1 unit at price 1970.300000, investment -0.785538 %, total balance 4639.480000,
# day 2249: buy 1 unit at price 1946.500000, total balance 2692.980000
# day 2250, sell 1 unit at price 1947.000000, investment -1.978553 %, total balance 4639.980000,
# day 2251, sell 1 unit at price 1939.200000, investment -4.047501 %, total balance 6579.180000,
# day 2252: buy 1 unit at price 1923.100000, total balance 4656.080000
# day 2253, sell 1 unit at price 1952.500000, investment -4.723564 %, total balance 6608.580000,
# day 2254, sell 1 unit at price 1932.600000, investment -0.714102 %, total balance 8541.180000,
# day 2255: buy 1 unit at price 1974.900000, total balance 6566.280000
# day 2257, sell 1 unit at price 1978.900000, investment 2.901565 %, total balance 8545.180000,
# day 2259, sell 1 unit at price 1937.800000, investment -1.878576 %, total balance 10482.980000,
# day 2260: buy 1 unit at price 1934.300000, total balance 8548.680000
# day 2261, sell 1 unit at price 1940.650000, investment 0.328284 %, total balance 10489.330000,
# day 2269: buy 1 unit at price 1970.500000, total balance 8518.830000
# day 2273: buy 1 unit at price 1907.600000, total balance 6611.230000
# day 2275: buy 1 unit at price 1876.900000, total balance 4734.330000
# day 2276: buy 1 unit at price 1866.300000, total balance 2868.030000
# day 2277, sell 1 unit at price 1882.300000, investment -4.476021 %, total balance 4750.330000,
# day 2279, sell 1 unit at price 1895.500000, investment -0.634305 %, total balance 6645.830000,
# day 2281: buy 1 unit at price 1907.600000, total balance 4738.230000
# day 2284, sell 1 unit at price 1890.800000, investment 0.740583 %, total balance 6629.030000,
# day 2285, sell 1 unit at price 1895.100000, investment 1.543160 %, total balance 8524.130000,
# day 2286, sell 1 unit at price 1926.200000, investment 0.975047 %, total balance 10450.330000,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-198b130142b3> in <module>()
# ----> 1 fig = plt.figure(figsize = (15,5))
#       2 plt.plot(close, color='r', lw=2.)
#       3 plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
#       4 plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
#       5 plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
#
# NameError: name 'plt' is not defined
